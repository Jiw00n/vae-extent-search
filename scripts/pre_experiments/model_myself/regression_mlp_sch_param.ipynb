# %%
import os
import sys
import re

project_root = "/root/work/tenset"
os.environ["TVM_HOME"] = f"{project_root}"
os.environ["TVM_LIBRARY_PATH"] = f"{project_root}/build"
if f"{project_root}/python" not in sys.path:
    sys.path.insert(0, f"{project_root}/python")

sys.path = [p for p in sys.path if not p.startswith(f"{project_root}/build")]
sys.path.append(f"{project_root}/build")
os.environ["LD_LIBRARY_PATH"] = f"{project_root}/build:" + os.environ.get("LD_LIBRARY_PATH", "")

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class NpzRegressionDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X).float()
        self.y = torch.from_numpy(y).float()
        # y shape이 (N,)이면 (N,1)로 바꿔주는 게 편할 때가 많음
        if self.y.ndim == 1:
            self.y = self.y.unsqueeze(1)

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

import torch.nn as nn



class MLPRegressor(nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, out_dim),
        )

    def forward(self, x):
        return self.net(x)

# %%
import numpy as np
import torch

# record_index
# vector_index
# diff_indices
# diff_values
# cost

json_diffs = np.load("i_vectors_diffs.npz")

input_data = np.log(json_diffs["diff_values"]+1e-8)
# input_data = json_diffs["diff_values"]
cost = -np.log(json_diffs["cost"])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_val, y_train, y_val = train_test_split(
    input_data, cost, test_size=0.2, random_state=42
)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)

train_dataset = NpzRegressionDataset(X_train_scaled, y_train)
val_dataset   = NpzRegressionDataset(X_val_scaled,   y_val)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=128, shuffle=False)

# %%
num_epochs = 100
input_dim = X_train.shape[1]
output_dim = 1
model = MLPRegressor(input_dim, output_dim)


criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

for epoch in range(num_epochs):
    # --- train ---
    model.train()
    train_loss = 0.0
    for xb, yb in train_loader:
        xb = xb.to(device)
        yb = yb.to(device)

        pred = model(xb)
        loss = criterion(pred, yb)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * xb.size(0)

    train_loss /= len(train_dataset)

    # --- validation ---
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for xb, yb in val_loader:
            xb = xb.to(device)
            yb = yb.to(device)

            pred = model(xb)
            loss = criterion(pred, yb)
            val_loss += loss.item() * xb.size(0)

    val_loss /= len(val_dataset)

    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"train_loss={train_loss:.4f} val_loss={val_loss:.4f}")
# Out:
# Epoch [1/100] train_loss=15.2328 val_loss=3.0228
# Epoch [2/100] train_loss=2.4433 val_loss=1.3649
# Epoch [3/100] train_loss=1.1367 val_loss=0.8493
# Epoch [4/100] train_loss=0.8275 val_loss=0.6965
# Epoch [5/100] train_loss=0.6799 val_loss=0.5936
# Epoch [6/100] train_loss=0.5879 val_loss=0.5446
# Epoch [7/100] train_loss=0.5061 val_loss=0.4729
# Epoch [8/100] train_loss=0.4488 val_loss=0.4311
# Epoch [9/100] train_loss=0.3924 val_loss=0.3994
# Epoch [10/100] train_loss=0.3390 val_loss=0.3649
# Epoch [11/100] train_loss=0.2992 val_loss=0.3420
# Epoch [12/100] train_loss=0.2661 val_loss=0.3175
# Epoch [13/100] train_loss=0.2425 val_loss=0.3178
# Epoch [14/100] train_loss=0.2226 val_loss=0.2818
# Epoch [15/100] train_loss=0.1989 val_loss=0.2775
# Epoch [16/100] train_loss=0.1825 val_loss=0.2538
# Epoch [17/100] train_loss=0.1653 val_loss=0.2441
# Epoch [64/100] train_loss=0.0230 val_loss=0.1424
# Epoch [65/100] train_loss=0.0247 val_loss=0.1553
# Epoch [66/100] train_loss=0.0252 val_loss=0.1322
# Epoch [67/100] train_loss=0.0217 val_loss=0.1384
# Epoch [68/100] train_loss=0.0229 val_loss=0.1335
# Epoch [69/100] train_loss=0.0212 val_loss=0.1389
# Epoch [70/100] train_loss=0.0202 val_loss=0.1374
# Epoch [71/100] train_loss=0.0191 val_loss=0.1324
# Epoch [72/100] train_loss=0.0179 val_loss=0.1287
# Epoch [73/100] train_loss=0.0195 val_loss=0.1330
# Epoch [74/100] train_loss=0.0173 val_loss=0.1353
# Epoch [75/100] train_loss=0.0162 val_loss=0.1319
# Epoch [76/100] train_loss=0.0161 val_loss=0.1378
# Epoch [77/100] train_loss=0.0161 val_loss=0.1292
# Epoch [78/100] train_loss=0.0151 val_loss=0.1393
# Epoch [79/100] train_loss=0.0189 val_loss=0.1413
# Epoch [80/100] train_loss=0.0169 val_loss=0.1348
# Epoch [81/100] train_loss=0.0166 val_loss=0.1342
# Epoch [82/100] train_loss=0.0179 val_loss=0.1310
# Epoch [83/100] train_loss=0.0173 val_loss=0.1327
# Epoch [84/100] train_loss=0.0174 val_loss=0.1328
# Epoch [85/100] train_loss=0.0139 val_loss=0.1302
# Epoch [86/100] train_loss=0.0149 val_loss=0.1363
# Epoch [87/100] train_loss=0.0147 val_loss=0.1277
# Epoch [88/100] train_loss=0.0149 val_loss=0.1351
# Epoch [89/100] train_loss=0.0152 val_loss=0.1291
# Epoch [90/100] train_loss=0.0149 val_loss=0.1300
# Epoch [91/100] train_loss=0.0159 val_loss=0.1250
# Epoch [92/100] train_loss=0.0135 val_loss=0.1277
# Epoch [93/100] train_loss=0.0143 val_loss=0.1335
# Epoch [94/100] train_loss=0.0159 val_loss=0.1370
# Epoch [95/100] train_loss=0.0141 val_loss=0.1346
# Epoch [96/100] train_loss=0.0131 val_loss=0.1274
# Epoch [97/100] train_loss=0.0129 val_loss=0.1338
# Epoch [98/100] train_loss=0.0149 val_loss=0.1330
# Epoch [99/100] train_loss=0.0159 val_loss=0.1335
# Epoch [100/100] train_loss=0.0175 val_loss=0.1381

# %%
import matplotlib.font_manager
print([f.fname for f in matplotlib.font_manager.fontManager.ttflist])
# Out:
# ['/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumGothicBold.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumMyeongjo.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumPen.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumBrush.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumMyeongjoEcoBold.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumGothicLight.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumGothicEcoBold.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumGothicExtraBold.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumSquareRoundR.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumGothic.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumMyeongjoEco.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumBarunGothic.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumGothicEco.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumBarunpenR.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumGothicEcoExtraBold.ttf', '/root/work/tenset/.venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/NanumBarunGothicLig ...
